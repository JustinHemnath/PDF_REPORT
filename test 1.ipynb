# %%
import json
import pandas as pd
from typing import List, Dict
from itertools import groupby
import math

with open("ward_alangulam.json", "r", encoding="utf-8") as f:
    res = json.load(f)
    idx_data = res["index_data"]

df = pd.DataFrame(idx_data)


class COMPARE_TYPE:
    AC = "ac"
    LOCAL_BODY = "local_body"
    BOOTH = "booth"
    LOCALITY = "locality"
    WARD = "ward_vp"

# %%
def add_index_row_style(
    source_row_data: List, should_add_booths_per_lb: bool, compare_type
):
    modified_row_data: List = []

    if compare_type in [COMPARE_TYPE.LOCALITY, COMPARE_TYPE.WARD]:
        sub_group_key = compare_type # compare_type would be "locality" or "ward_vp"
        
        df = pd.DataFrame(source_row_data)
        lb_list = df["lb_name"].unique().tolist()
        
        ## set sl no based on lb names
        lb_dict_with_sl_no = { lb_name : idx+1 for idx, lb_name in enumerate(lb_list) }
        for index_item in source_row_data:
            index_item["s_no"] = lb_dict_with_sl_no[index_item["lb_name"]]

        ## lb wise total booth count
        for lb_name in lb_list:
            matching_records_df = df[(df["lb_name"] == lb_name)]
            total = matching_records_df["booth_count"].sum()
            index_list = matching_records_df.index.tolist()

            for idx in index_list:
                source_row_data[idx]["lb_wise_booth_count"] = int(total)

        ## ward_vp/locality wise total booth count
        ward_list = df[["lb_name", sub_group_key]]
        new_ward_list = set(ward_list.to_records(index=None).tolist())
        
        for lb_name, ward_vp in new_ward_list:
            matching_records_df = df[(df["lb_name"] == lb_name) & (df[sub_group_key] == ward_vp)]
            total = matching_records_df["booth_count"].sum()
            index_list = matching_records_df.index.tolist()

            for idx in index_list:
                source_row_data[idx]["ward_wise_booth_count"] = int(total)
        
        ## trend wise total booth count
        trend_list_mapping = df[["lb_name", "ward_vp", "trend"]]
        new_trend_list_mapping = set(trend_list_mapping.to_records(index=None).tolist())

        for lb_name, ward_vp, trend in new_trend_list_mapping:
            matching_records_df = df[(df["lb_name"] == lb_name) & (df["ward_vp"] == ward_vp) & (df["trend"] == trend)]
            total = matching_records_df["booth_count"].sum()
            index_list = matching_records_df.index.tolist()

            for idx in index_list:
                source_row_data[idx]["trend_wise_booth_count"] = int(total)

        # pd.DataFrame(source_row_data)
        return source_row_data
        
    else:
        is_dark_theme: bool = True

        grouped_data = groupby(source_row_data, lambda x: x["lb_name"])

        current_trend = None
        current_parent_name = None

        for key, value in grouped_data:
            is_dark_theme = not is_dark_theme

            list_value = list(value)
            length = len(list_value)

            total_booth_count = 0
            for idx, item in enumerate(list_value):
                if idx == 0:
                    item["add_thick_border"] = True

                if current_trend == None and current_parent_name == None:
                    item["has_top_line"] = True
                    current_trend = item["trend"]
                    current_parent_name = item["lb_name"]
                elif (
                    item["lb_name"] == current_parent_name
                    and item["trend"] == current_trend
                ):
                    item["has_top_line"] = False
                else:
                    item["has_top_line"] = True
                    current_trend = item["trend"]
                    current_parent_name = item["lb_name"]

                item["row_theme"] = is_dark_theme

                if should_add_booths_per_lb:
                    total_booth_count += item["booth_count"]

                # if last item, add the total booth count value for it to be displayed in the index data
                if idx + 1 == length:
                    item["total_booth_count"] = total_booth_count

                modified_row_data.append(item)

        # get total booth count per local body and trend
        current_lb = None
        current_trend = None
        first_trendwise_idx = None
        booth_count_per_trend = 0

        total_length = len(modified_row_data)

        for current_idx, current_row in enumerate(modified_row_data):
            # initial set up even before the first row is iterated
            if (current_lb and current_trend and first_trendwise_idx) == None:
                current_lb = current_row["lb_name"]
                current_trend = current_row["trend"]
                first_trendwise_idx = current_idx

            # if lb and trend match, get the booth count from the row and add to the total booth count
            belongs_to_lb_trend_bucket = (
                current_lb == current_row["lb_name"]
                and current_trend == current_row["trend"]
            )

            if belongs_to_lb_trend_bucket:
                booth_count_per_trend += current_row["booth_count"]

                # if row is the last item and doesnt match the previous bucket
                if total_length == current_idx + 1:
                    prev_first_row = modified_row_data[first_trendwise_idx]
                    prev_first_row["total_booth_count_per_trend"] = (
                        booth_count_per_trend
                    )
            else:
                prev_first_row = modified_row_data[first_trendwise_idx]
                prev_first_row["total_booth_count_per_trend"] = booth_count_per_trend

                booth_count_per_trend = current_row["booth_count"]
                current_lb = current_row["lb_name"]
                current_trend = current_row["trend"]
                first_trendwise_idx = current_idx

                # if row is the last item and doesnt match the previous bucket
                if total_length == current_idx + 1:
                    current_row["total_booth_count_per_trend"] = booth_count_per_trend

    #
    #
    #

    return modified_row_data

def add_other_table_row_style(source_row_data: List, should_add_booths_per_lb: bool):
    is_dark_theme: bool = True
    modified_row_data: List = []

    grouped_data = groupby(source_row_data, lambda x: x["lb_name"])

    for key, value in grouped_data:
        is_dark_theme = not is_dark_theme

        list_value = list(value)
        length = len(list_value)

        total_booth_count = 0
        for idx, item in enumerate(list_value):
            item["row_theme"] = is_dark_theme

            if should_add_booths_per_lb:
                total_booth_count += item["booth_count"]

            # if last item, add the total booth count value for it to be displayed in the index data
            if idx + 1 == length:
                item["total_booth_count"] = total_booth_count

            modified_row_data.append(item)

    return modified_row_data

def merge_index_table_rows(index_table_data: list, compare_type) -> List:
    grouped_index_table_data = []

    if compare_type in [COMPARE_TYPE.WARD, COMPARE_TYPE.LOCALITY]:
        for index_page_obj in index_table_data:
            new_page_data = dict() 
            for index_item in index_page_obj["page_data"]["page_data"]:

                new_page_data = {
                    **new_page_data,
                    index_item["lb_name"]: {
                        "meta": {
                            "lb_type": index_item["lb_type"],
                            "total_booths": index_item["lb_wise_booth_count"],
                        },
                        "data": {
                            **new_page_data.get(index_item["lb_name"], {}).get("data", {}),
                            index_item[compare_type]: {
                                "meta": {
                                    "total_booths": index_item["ward_wise_booth_count"],
                                    "ward_type": index_item["ward_vp_type"],
                                },
                                "data": {
                                    **new_page_data.get(index_item["lb_name"], {}).get("data", {}).get(index_item[compare_type], {}).get("data", {}),
                                    index_item["trend"]: {
                                        "meta": {
                                            "total_booths": index_item["trend_wise_booth_count"],
                                        },
                                        "data": [
                                            *new_page_data.get(index_item["lb_name"], {}).get("data", {}).get(index_item[compare_type], {}).get("data", {}).get(index_item["trend"], {}).get("data", []),
                                            index_item,
                                        ]
                                    }
                                }
                            }
                        }
                    }
                }


            index_page_obj["page_data"]["grouped_page_data"] = new_page_data
        
        return index_table_data
    else:
        return index_table_data

# %%
# add_index_row_style(idx_data, True, COMPARE_TYPE.WARD)

page_data = add_index_row_style(idx_data, True, COMPARE_TYPE.WARD)
pd.DataFrame(page_data).head(80)

# with open("new.json", "w", encoding="utf-8") as f:
#     f.write(json.dumps(page_data, ensure_ascii=False))
# Out:
#              lb_name   lb_type          ward_vp ward_vp_type      booth_list  \
# 0   ஆலங்குளம் தெற்கு  ஒன்றியம்  மாயமான்குரிச்சி           vp            [78]
# 1   ஆலங்குளம் தெற்கு  ஒன்றியம்  மாயமான்குரிச்சி           vp     [76, 81-85]
# 2   ஆலங்குளம் தெற்கு  ஒன்றியம்  மாயமான்குரிச்சி           vp            [77]
# 3   ஆலங்குளம் தெற்கு  ஒன்றியம்        நாரணபுரம்           vp     [79,80, 86]
# 4   ஆலங்குளம் தெற்கு  ஒன்றியம்        கடங்கநேரி           vp           [107]
# ..               ...       ...              ...          ...             ...
# 75     கடையம் தெற்கு  ஒன்றியம்    பொட்டல்புதூர்           vp           [255]
# 76     கடையம் தெற்கு  ஒன்றியம்    பொட்டல்புதூர்           vp           [253]
# 77     கடையம் தெற்கு  ஒன்றியம்    பாப்பான்குளம்           vp           [258]
# 78     கடையம் தெற்கு  ஒன்றியம்    பாப்பான்குளம்           vp  [257, 259-261]
# 79     கடையம் தெற்கு  ஒன்றியம்   வீராசமுத்திரம்           vp           [248]
#
#          booth_list_expanded  booth_count trend sub_trend  page_no  s_no  \
# 0                       [78]            1    WW        SS        2     1
# 1   [76, 81, 82, 83, 84, 85]            6    WL        SD        2     1
# 2                       [77]            1    LL        DD        2     1
# 3               [79, 80, 86]            3    WW        SS        2     1
# 4                      [107]            1    WW        SS        2     1
# ..                       ...          ...   ...       ...      ...   ...
# 75                     [255]            1    LW        DS        9     4
# 76                     [253]            1    LL        DB        9     4
# 77                     [258]            1    WW        SS        9     4
# 78      [257, 259, 260, 261]            4    WL        SD        9     4
# 79                     [248]            1    WW        FS        9     4
#
#    page_no_list  lb_wise_booth_count  ward_wise_booth_count  \
# 0         3 - 4                   56                      8
# 1         5 - 8                   56                      8
# 2        9 - 10                   56                      8
# 3       11 - 13                   56                      3
# 4       14 - 15                   56                      8
# ..          ...                  ...                    ...
# 75    168 - 169                   46                      7
# 76    170 - 171                   46                      7
# 77    172 - 173                   46                      5
# 78    174 - 176                   46                      5
# 79    177 - 178                   46                      2
#
#     trend_wise_booth_count
# 0                        1
# 1                        6
# 2                        1
# 3                        3
# 4                        2
# ..                     ...
# 75                       1
# 76                       1
# 77                       1
# 78                       4
# 79                       1
#
# [80 rows x 15 columns]

# %%
def get_page_obj(pg_no, page_data) -> Dict:
    return {"page_number": str(pg_no), "page_data": page_data}


def get_total_hierarchy_item_count(data_to_loop: List, KEY_TO_LOOKUP: str):
    count = 0
    for item in data_to_loop:
        count += item[KEY_TO_LOOKUP]
    return count


def group_table_pages_data(
    response_data: Dict,
    ITEMS_PER_PAGE: int,
    should_set_row_style: bool,
    should_add_booths_per_lb: bool,
    is_get_total_hierarchy_item_count: bool,
    TABLE_KEY_TO_LOOKUP: str,
    should_sort: bool,
    is_index_table: bool,
    compare_type: str,
):
    if len(response_data) == 0:
        return []

    if should_sort:
        response_data = sorted(response_data, key=lambda x: x["booth_no"])
    
    ## set alternating row style based on the local body name
    if should_set_row_style:
        if is_index_table:
            page_data = add_index_row_style(response_data, should_add_booths_per_lb, compare_type)
        else:
            page_data = add_other_table_row_style(
                response_data, should_add_booths_per_lb
            )
    else:
        page_data = response_data
    page_item_count = len(page_data)
    final_page_data = []

    if page_item_count < ITEMS_PER_PAGE:
        final_page_data.append(
            get_page_obj(
                "",
                {
                    "total_count_per_table": (
                        get_total_hierarchy_item_count(
                            data_to_loop=page_data, KEY_TO_LOOKUP=TABLE_KEY_TO_LOOKUP
                        )
                        if is_get_total_hierarchy_item_count
                        else None
                    ),
                    "page_data": page_data,
                },
            )
        )
    else:
        number_of_iterations = math.ceil(page_item_count / ITEMS_PER_PAGE)
        slice_from = 0
        slice_till = 0 + ITEMS_PER_PAGE

        for x in range(number_of_iterations):
            sliced_page_data = page_data[slice_from:slice_till]

            final_page_data.append(
                get_page_obj(
                    "",
                    {
                        "total_count_per_table": (
                            get_total_hierarchy_item_count(
                                data_to_loop=sliced_page_data,
                                KEY_TO_LOOKUP=TABLE_KEY_TO_LOOKUP,
                            )
                            if is_get_total_hierarchy_item_count
                            else None
                        ),
                        "page_data": sliced_page_data,
                    },
                )
            )
            slice_from = slice_from + ITEMS_PER_PAGE
            slice_till = slice_till + ITEMS_PER_PAGE
    
    
    # does grouping of the index data items in order to group and merge the rows as per lb, locality/ward_vp wise
    # should do only for the index table, not for summary or appendix table
    if is_index_table and should_set_row_style:
        final_page_data = merge_index_table_rows(final_page_data, compare_type)

    return final_page_data


index_data_pages = group_table_pages_data(
    response_data=idx_data,
    ITEMS_PER_PAGE=15,
    should_set_row_style=True,
    should_add_booths_per_lb=True,
    is_get_total_hierarchy_item_count=True,
    TABLE_KEY_TO_LOOKUP="booth_count",
    should_sort=False,
    is_index_table=True,
    compare_type=COMPARE_TYPE.WARD,
)

# pd.DataFrame(index_data_pages)
index_data_pages
# Out:
# [{'page_number': '',
#   'page_data': {'total_count_per_table': 29,
#    'page_data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'மாயமான்குரிச்சி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['78'],
#      'booth_list_expanded': [78],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 2,
#      's_no': 1,
#      'page_no_list': '3 - 4',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'மாயமான்குரிச்சி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['76', '81-85'],
#      'booth_list_expanded': [76, 81, 82, 83, 84, 85],
#      'booth_count': 6,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 2,
#      's_no': 2,
#      'page_no_list': '5 - 8',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 6},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'மாயமான்குரிச்சி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['77'],
#      'booth_list_expanded': [77],
#      'booth_count': 1,
#      'trend': 'LL',
#      'sub_trend': 'DD',
#      'page_no': 2,
#      's_no': 3,
#      'page_no_list': '9 - 10',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'நாரணபுரம்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['79,80', '86'],
#      'booth_list_expanded': [79, 80, 86],
#      'booth_count': 3,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 2,
#      's_no': 4,
#      'page_no_list': '11 - 13',
#      'ward_wise_booth_count': 3,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 3},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'கடங்கநேரி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['107'],
#      'booth_list_expanded': [107],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 2,
#      's_no': 5,
#      'page_no_list': '14 - 15',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 2},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'கடங்கநேரி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['100'],
#      'booth_list_expanded': [100],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'FF',
#      'page_no': 2,
#      's_no': 6,
#      'page_no_list': '16 - 17',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 2},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'கடங்கநேரி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['101', '104', '106'],
#      'booth_list_expanded': [101, 104, 106],
#      'booth_count': 3,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 2,
#      's_no': 7,
#      'page_no_list': '18 - 20',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 4},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'கடங்கநேரி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['103'],
#      'booth_list_expanded': [103],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'FD',
#      'page_no': 2,
#      's_no': 8,
#      'page_no_list': '21 - 22',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 4},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'கடங்கநேரி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['99', '102'],
#      'booth_list_expanded': [99, 102],
#      'booth_count': 2,
#      'trend': 'LL',
#      'sub_trend': 'DD',
#      'page_no': 2,
#      's_no': 9,
#      'page_no_list': '23 - 24',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 2},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'சுப்பையாபுரம்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['108'],
#      'booth_list_expanded': [108],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 2,
#      's_no': 10,
#      'page_no_list': '25 - 26',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'மாறாந்தை',
#      'ward_vp_type': 'vp',
#      'booth_list': ['112-114'],
#      'booth_list_expanded': [112, 113, 114],
#      'booth_count': 3,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 3,
#      's_no': 11,
#      'page_no_list': '27 - 29',
#      'ward_wise_booth_count': 6,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 3},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'மாறாந்தை',
#      'ward_vp_type': 'vp',
#      'booth_list': ['111'],
#      'booth_list_expanded': [111],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 3,
#      's_no': 12,
#      'page_no_list': '30 - 31',
#      'ward_wise_booth_count': 6,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'மாறாந்தை',
#      'ward_vp_type': 'vp',
#      'booth_list': ['110'],
#      'booth_list_expanded': [110],
#      'booth_count': 1,
#      'trend': 'LW',
#      'sub_trend': 'DS',
#      'page_no': 3,
#      's_no': 13,
#      'page_no_list': '32 - 33',
#      'ward_wise_booth_count': 6,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'மாறாந்தை',
#      'ward_vp_type': 'vp',
#      'booth_list': ['109'],
#      'booth_list_expanded': [109],
#      'booth_count': 1,
#      'trend': 'LL',
#      'sub_trend': 'DD',
#      'page_no': 3,
#      's_no': 14,
#      'page_no_list': '34 - 35',
#      'ward_wise_booth_count': 6,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'சிவலார்குளம்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['115-117'],
#      'booth_list_expanded': [115, 116, 117],
#      'booth_count': 3,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 3,
#      's_no': 15,
#      'page_no_list': '36 - 38',
#      'ward_wise_booth_count': 3,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 3}],
#    'grouped_page_data': {'ஆலங்குளம் தெற்கு': {'meta': {'lb_type': 'ஒன்றியம்',
#       'total_booths': 56},
#      'data': {'மாயமான்குரிச்சி': {'meta': {'total_booths': 8,
#         'ward_type': 'vp'},
#        'data': {'WW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'மாயமான்குரிச்சி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['78'],
#            'booth_list_expanded': [78],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 2,
#            's_no': 1,
#            'page_no_list': '3 - 4',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]},
#         'WL': {'meta': {'total_booths': 6},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'மாயமான்குரிச்சி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['76', '81-85'],
#            'booth_list_expanded': [76, 81, 82, 83, 84, 85],
#            'booth_count': 6,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 2,
#            's_no': 2,
#            'page_no_list': '5 - 8',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 6}]},
#         'LL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'மாயமான்குரிச்சி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['77'],
#            'booth_list_expanded': [77],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 2,
#            's_no': 3,
#            'page_no_list': '9 - 10',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]}}},
#       'நாரணபுரம்': {'meta': {'total_booths': 3, 'ward_type': 'vp'},
#        'data': {'WW': {'meta': {'total_booths': 3},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'நாரணபுரம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['79,80', '86'],
#            'booth_list_expanded': [79, 80, 86],
#            'booth_count': 3,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 2,
#            's_no': 4,
#            'page_no_list': '11 - 13',
#            'ward_wise_booth_count': 3,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 3}]}}},
#       'கடங்கநேரி': {'meta': {'total_booths': 8, 'ward_type': 'vp'},
#        'data': {'WW': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'கடங்கநேரி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['107'],
#            'booth_list_expanded': [107],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 2,
#            's_no': 5,
#            'page_no_list': '14 - 15',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 2},
#           {'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'கடங்கநேரி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['100'],
#            'booth_list_expanded': [100],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'FF',
#            'page_no': 2,
#            's_no': 6,
#            'page_no_list': '16 - 17',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 2}]},
#         'WL': {'meta': {'total_booths': 4},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'கடங்கநேரி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['101', '104', '106'],
#            'booth_list_expanded': [101, 104, 106],
#            'booth_count': 3,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 2,
#            's_no': 7,
#            'page_no_list': '18 - 20',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 4},
#           {'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'கடங்கநேரி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['103'],
#            'booth_list_expanded': [103],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'FD',
#            'page_no': 2,
#            's_no': 8,
#            'page_no_list': '21 - 22',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 4}]},
#         'LL': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'கடங்கநேரி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['99', '102'],
#            'booth_list_expanded': [99, 102],
#            'booth_count': 2,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 2,
#            's_no': 9,
#            'page_no_list': '23 - 24',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 2}]}}},
#       'சுப்பையாபுரம்': {'meta': {'total_booths': 1, 'ward_type': 'vp'},
#        'data': {'WW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'சுப்பையாபுரம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['108'],
#            'booth_list_expanded': [108],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 2,
#            's_no': 10,
#            'page_no_list': '25 - 26',
#            'ward_wise_booth_count': 1,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]}}},
#       'மாறாந்தை': {'meta': {'total_booths': 6, 'ward_type': 'vp'},
#        'data': {'WW': {'meta': {'total_booths': 3},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'மாறாந்தை',
#            'ward_vp_type': 'vp',
#            'booth_list': ['112-114'],
#            'booth_list_expanded': [112, 113, 114],
#            'booth_count': 3,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 3,
#            's_no': 11,
#            'page_no_list': '27 - 29',
#            'ward_wise_booth_count': 6,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 3}]},
#         'WL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'மாறாந்தை',
#            'ward_vp_type': 'vp',
#            'booth_list': ['111'],
#            'booth_list_expanded': [111],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 3,
#            's_no': 12,
#            'page_no_list': '30 - 31',
#            'ward_wise_booth_count': 6,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]},
#         'LW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'மாறாந்தை',
#            'ward_vp_type': 'vp',
#            'booth_list': ['110'],
#            'booth_list_expanded': [110],
#            'booth_count': 1,
#            'trend': 'LW',
#            'sub_trend': 'DS',
#            'page_no': 3,
#            's_no': 13,
#            'page_no_list': '32 - 33',
#            'ward_wise_booth_count': 6,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]},
#         'LL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'மாறாந்தை',
#            'ward_vp_type': 'vp',
#            'booth_list': ['109'],
#            'booth_list_expanded': [109],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 3,
#            's_no': 14,
#            'page_no_list': '34 - 35',
#            'ward_wise_booth_count': 6,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]}}},
#       'சிவலார்குளம்': {'meta': {'total_booths': 3, 'ward_type': 'vp'},
#        'data': {'WW': {'meta': {'total_booths': 3},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'சிவலார்குளம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['115-117'],
#            'booth_list_expanded': [115, 116, 117],
#            'booth_count': 3,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 3,
#            's_no': 15,
#            'page_no_list': '36 - 38',
#            'ward_wise_booth_count': 3,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 3}]}}}}}}}},
#  {'page_number': '',
#   'page_data': {'total_count_per_table': 21,
#    'page_data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'நல்லூர்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['122'],
#      'booth_list_expanded': [122],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 3,
#      's_no': 16,
#      'page_no_list': '39 - 40',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 3},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'நல்லூர்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['123'],
#      'booth_list_expanded': [123],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'FF',
#      'page_no': 3,
#      's_no': 17,
#      'page_no_list': '41 - 42',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 3},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'நல்லூர்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['121'],
#      'booth_list_expanded': [121],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'FS',
#      'page_no': 3,
#      's_no': 18,
#      'page_no_list': '43 - 44',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 3},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'நல்லூர்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['118-120', '125'],
#      'booth_list_expanded': [118, 119, 120, 125],
#      'booth_count': 4,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 3,
#      's_no': 19,
#      'page_no_list': '45 - 47',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 4},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'நல்லூர்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['124'],
#      'booth_list_expanded': [124],
#      'booth_count': 1,
#      'trend': 'LL',
#      'sub_trend': 'BD',
#      'page_no': 3,
#      's_no': 20,
#      'page_no_list': '48 - 49',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'குறிப்பன்குளம்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['72,73'],
#      'booth_list_expanded': [72, 73],
#      'booth_count': 2,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 4,
#      's_no': 21,
#      'page_no_list': '50 - 51',
#      'ward_wise_booth_count': 4,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 2},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'குறிப்பன்குளம்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['75'],
#      'booth_list_expanded': [75],
#      'booth_count': 1,
#      'trend': 'LW',
#      'sub_trend': 'BS',
#      'page_no': 4,
#      's_no': 22,
#      'page_no_list': '52 - 53',
#      'ward_wise_booth_count': 4,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'குறிப்பன்குளம்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['74'],
#      'booth_list_expanded': [74],
#      'booth_count': 1,
#      'trend': 'LL',
#      'sub_trend': 'DD',
#      'page_no': 4,
#      's_no': 23,
#      'page_no_list': '54 - 55',
#      'ward_wise_booth_count': 4,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'கிடாரகுளம்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['88'],
#      'booth_list_expanded': [88],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 4,
#      's_no': 24,
#      'page_no_list': '56 - 57',
#      'ward_wise_booth_count': 2,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'கிடாரகுளம்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['87'],
#      'booth_list_expanded': [87],
#      'booth_count': 1,
#      'trend': 'LW',
#      'sub_trend': 'DS',
#      'page_no': 4,
#      's_no': 25,
#      'page_no_list': '58 - 59',
#      'ward_wise_booth_count': 2,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'நெட்டூர்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['91'],
#      'booth_list_expanded': [91],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 4,
#      's_no': 26,
#      'page_no_list': '60 - 61',
#      'ward_wise_booth_count': 5,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 2},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'நெட்டூர்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['89'],
#      'booth_list_expanded': [89],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'FD',
#      'page_no': 4,
#      's_no': 27,
#      'page_no_list': '62 - 63',
#      'ward_wise_booth_count': 5,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 2},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'நெட்டூர்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['90'],
#      'booth_list_expanded': [90],
#      'booth_count': 1,
#      'trend': 'LW',
#      'sub_trend': 'DS',
#      'page_no': 4,
#      's_no': 28,
#      'page_no_list': '64 - 65',
#      'ward_wise_booth_count': 5,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'நெட்டூர்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['92,93'],
#      'booth_list_expanded': [92, 93],
#      'booth_count': 2,
#      'trend': 'LL',
#      'sub_trend': 'DD',
#      'page_no': 4,
#      's_no': 29,
#      'page_no_list': '66 - 67',
#      'ward_wise_booth_count': 5,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 2},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'காவலாகுறிச்சி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['95', '98'],
#      'booth_list_expanded': [95, 98],
#      'booth_count': 2,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 4,
#      's_no': 30,
#      'page_no_list': '68 - 69',
#      'ward_wise_booth_count': 5,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 2}],
#    'grouped_page_data': {'ஆலங்குளம் தெற்கு': {'meta': {'lb_type': 'ஒன்றியம்',
#       'total_booths': 56},
#      'data': {'நல்லூர்': {'meta': {'total_booths': 8, 'ward_type': 'vp'},
#        'data': {'WW': {'meta': {'total_booths': 3},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'நல்லூர்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['122'],
#            'booth_list_expanded': [122],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 3,
#            's_no': 16,
#            'page_no_list': '39 - 40',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 3},
#           {'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'நல்லூர்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['123'],
#            'booth_list_expanded': [123],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'FF',
#            'page_no': 3,
#            's_no': 17,
#            'page_no_list': '41 - 42',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 3},
#           {'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'நல்லூர்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['121'],
#            'booth_list_expanded': [121],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'FS',
#            'page_no': 3,
#            's_no': 18,
#            'page_no_list': '43 - 44',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 3}]},
#         'WL': {'meta': {'total_booths': 4},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'நல்லூர்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['118-120', '125'],
#            'booth_list_expanded': [118, 119, 120, 125],
#            'booth_count': 4,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 3,
#            's_no': 19,
#            'page_no_list': '45 - 47',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 4}]},
#         'LL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'நல்லூர்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['124'],
#            'booth_list_expanded': [124],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'BD',
#            'page_no': 3,
#            's_no': 20,
#            'page_no_list': '48 - 49',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]}}},
#       'குறிப்பன்குளம்': {'meta': {'total_booths': 4, 'ward_type': 'vp'},
#        'data': {'WL': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'குறிப்பன்குளம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['72,73'],
#            'booth_list_expanded': [72, 73],
#            'booth_count': 2,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 4,
#            's_no': 21,
#            'page_no_list': '50 - 51',
#            'ward_wise_booth_count': 4,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 2}]},
#         'LW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'குறிப்பன்குளம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['75'],
#            'booth_list_expanded': [75],
#            'booth_count': 1,
#            'trend': 'LW',
#            'sub_trend': 'BS',
#            'page_no': 4,
#            's_no': 22,
#            'page_no_list': '52 - 53',
#            'ward_wise_booth_count': 4,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]},
#         'LL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'குறிப்பன்குளம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['74'],
#            'booth_list_expanded': [74],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 4,
#            's_no': 23,
#            'page_no_list': '54 - 55',
#            'ward_wise_booth_count': 4,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]}}},
#       'கிடாரகுளம்': {'meta': {'total_booths': 2, 'ward_type': 'vp'},
#        'data': {'WL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'கிடாரகுளம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['88'],
#            'booth_list_expanded': [88],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 4,
#            's_no': 24,
#            'page_no_list': '56 - 57',
#            'ward_wise_booth_count': 2,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]},
#         'LW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'கிடாரகுளம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['87'],
#            'booth_list_expanded': [87],
#            'booth_count': 1,
#            'trend': 'LW',
#            'sub_trend': 'DS',
#            'page_no': 4,
#            's_no': 25,
#            'page_no_list': '58 - 59',
#            'ward_wise_booth_count': 2,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]}}},
#       'நெட்டூர்': {'meta': {'total_booths': 5, 'ward_type': 'vp'},
#        'data': {'WL': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'நெட்டூர்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['91'],
#            'booth_list_expanded': [91],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 4,
#            's_no': 26,
#            'page_no_list': '60 - 61',
#            'ward_wise_booth_count': 5,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 2},
#           {'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'நெட்டூர்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['89'],
#            'booth_list_expanded': [89],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'FD',
#            'page_no': 4,
#            's_no': 27,
#            'page_no_list': '62 - 63',
#            'ward_wise_booth_count': 5,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 2}]},
#         'LW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'நெட்டூர்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['90'],
#            'booth_list_expanded': [90],
#            'booth_count': 1,
#            'trend': 'LW',
#            'sub_trend': 'DS',
#            'page_no': 4,
#            's_no': 28,
#            'page_no_list': '64 - 65',
#            'ward_wise_booth_count': 5,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]},
#         'LL': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'நெட்டூர்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['92,93'],
#            'booth_list_expanded': [92, 93],
#            'booth_count': 2,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 4,
#            's_no': 29,
#            'page_no_list': '66 - 67',
#            'ward_wise_booth_count': 5,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 2}]}}},
#       'காவலாகுறிச்சி': {'meta': {'total_booths': 5, 'ward_type': 'vp'},
#        'data': {'WL': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'காவலாகுறிச்சி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['95', '98'],
#            'booth_list_expanded': [95, 98],
#            'booth_count': 2,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 4,
#            's_no': 30,
#            'page_no_list': '68 - 69',
#            'ward_wise_booth_count': 5,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 2}]}}}}}}}},
#  {'page_number': '',
#   'page_data': {'total_count_per_table': 20,
#    'page_data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'காவலாகுறிச்சி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['94'],
#      'booth_list_expanded': [94],
#      'booth_count': 1,
#      'trend': 'LW',
#      'sub_trend': 'DS',
#      'page_no': 5,
#      's_no': 31,
#      'page_no_list': '70 - 71',
#      'ward_wise_booth_count': 5,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'காவலாகுறிச்சி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['96,97'],
#      'booth_list_expanded': [96, 97],
#      'booth_count': 2,
#      'trend': 'LL',
#      'sub_trend': 'DD',
#      'page_no': 5,
#      's_no': 32,
#      'page_no_list': '72 - 73',
#      'ward_wise_booth_count': 5,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 2},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'அய்யனரர்குளம்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['126'],
#      'booth_list_expanded': [126],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'FD',
#      'page_no': 5,
#      's_no': 33,
#      'page_no_list': '74 - 75',
#      'ward_wise_booth_count': 2,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'அய்யனரர்குளம்',
#      'ward_vp_type': 'vp',
#      'booth_list': ['127'],
#      'booth_list_expanded': [127],
#      'booth_count': 1,
#      'trend': 'LL',
#      'sub_trend': 'DD',
#      'page_no': 5,
#      's_no': 34,
#      'page_no_list': '76 - 77',
#      'ward_wise_booth_count': 2,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் தெற்கு',
#      'lb_type': 'ஒன்றியம்',
#      'ward_vp': 'காடுவெட்டி',
#      'ward_vp_type': 'vp',
#      'booth_list': ['105'],
#      'booth_list_expanded': [105],
#      'booth_count': 1,
#      'trend': 'LW',
#      'sub_trend': 'DS',
#      'page_no': 5,
#      's_no': 35,
#      'page_no_list': '78 - 79',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 56,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '0',
#      'ward_vp_type': 'ward',
#      'booth_list': ['60', '67'],
#      'booth_list_expanded': [60, 67],
#      'booth_count': 2,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 5,
#      's_no': 36,
#      'page_no_list': '80 - 81',
#      'ward_wise_booth_count': 9,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 4},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '0',
#      'ward_vp_type': 'ward',
#      'booth_list': ['68'],
#      'booth_list_expanded': [68],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'SF',
#      'page_no': 5,
#      's_no': 37,
#      'page_no_list': '82 - 83',
#      'ward_wise_booth_count': 9,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 4},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '0',
#      'ward_vp_type': 'ward',
#      'booth_list': ['69'],
#      'booth_list_expanded': [69],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'BS',
#      'page_no': 5,
#      's_no': 38,
#      'page_no_list': '84 - 85',
#      'ward_wise_booth_count': 9,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 4},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '0',
#      'ward_vp_type': 'ward',
#      'booth_list': ['53', '58,59', '64'],
#      'booth_list_expanded': [53, 58, 59, 64],
#      'booth_count': 4,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 5,
#      's_no': 39,
#      'page_no_list': '86 - 88',
#      'ward_wise_booth_count': 9,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 4},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '0',
#      'ward_vp_type': 'ward',
#      'booth_list': ['62'],
#      'booth_list_expanded': [62],
#      'booth_count': 1,
#      'trend': 'LL',
#      'sub_trend': 'DD',
#      'page_no': 5,
#      's_no': 40,
#      'page_no_list': '89 - 90',
#      'ward_wise_booth_count': 9,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '13',
#      'ward_vp_type': 'ward',
#      'booth_list': ['71'],
#      'booth_list_expanded': [71],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 6,
#      's_no': 41,
#      'page_no_list': '91 - 92',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '9',
#      'ward_vp_type': 'ward',
#      'booth_list': ['65'],
#      'booth_list_expanded': [65],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'SF',
#      'page_no': 6,
#      's_no': 42,
#      'page_no_list': '93 - 94',
#      'ward_wise_booth_count': 2,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '9',
#      'ward_vp_type': 'ward',
#      'booth_list': ['66'],
#      'booth_list_expanded': [66],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 6,
#      's_no': 43,
#      'page_no_list': '95 - 96',
#      'ward_wise_booth_count': 2,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '3',
#      'ward_vp_type': 'ward',
#      'booth_list': ['54'],
#      'booth_list_expanded': [54],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 6,
#      's_no': 44,
#      'page_no_list': '97 - 98',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '4',
#      'ward_vp_type': 'ward',
#      'booth_list': ['55'],
#      'booth_list_expanded': [55],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 6,
#      's_no': 45,
#      'page_no_list': '99 - 100',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 1}],
#    'grouped_page_data': {'ஆலங்குளம் தெற்கு': {'meta': {'lb_type': 'ஒன்றியம்',
#       'total_booths': 56},
#      'data': {'காவலாகுறிச்சி': {'meta': {'total_booths': 5, 'ward_type': 'vp'},
#        'data': {'LW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'காவலாகுறிச்சி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['94'],
#            'booth_list_expanded': [94],
#            'booth_count': 1,
#            'trend': 'LW',
#            'sub_trend': 'DS',
#            'page_no': 5,
#            's_no': 31,
#            'page_no_list': '70 - 71',
#            'ward_wise_booth_count': 5,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]},
#         'LL': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'காவலாகுறிச்சி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['96,97'],
#            'booth_list_expanded': [96, 97],
#            'booth_count': 2,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 5,
#            's_no': 32,
#            'page_no_list': '72 - 73',
#            'ward_wise_booth_count': 5,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 2}]}}},
#       'அய்யனரர்குளம்': {'meta': {'total_booths': 2, 'ward_type': 'vp'},
#        'data': {'WL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'அய்யனரர்குளம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['126'],
#            'booth_list_expanded': [126],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'FD',
#            'page_no': 5,
#            's_no': 33,
#            'page_no_list': '74 - 75',
#            'ward_wise_booth_count': 2,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]},
#         'LL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'அய்யனரர்குளம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['127'],
#            'booth_list_expanded': [127],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 5,
#            's_no': 34,
#            'page_no_list': '76 - 77',
#            'ward_wise_booth_count': 2,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]}}},
#       'காடுவெட்டி': {'meta': {'total_booths': 1, 'ward_type': 'vp'},
#        'data': {'LW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் தெற்கு',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'காடுவெட்டி',
#            'ward_vp_type': 'vp',
#            'booth_list': ['105'],
#            'booth_list_expanded': [105],
#            'booth_count': 1,
#            'trend': 'LW',
#            'sub_trend': 'DS',
#            'page_no': 5,
#            's_no': 35,
#            'page_no_list': '78 - 79',
#            'ward_wise_booth_count': 1,
#            'lb_wise_booth_count': 56,
#            'trend_wise_booth_count': 1}]}}}}},
#     'ஆலங்குளம் பேரூர்': {'meta': {'lb_type': 'பேரூராட்சி', 'total_booths': 19},
#      'data': {'0': {'meta': {'total_booths': 9, 'ward_type': 'ward'},
#        'data': {'WW': {'meta': {'total_booths': 4},
#          'data': [{'lb_name': 'ஆலங்குளம் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '0',
#            'ward_vp_type': 'ward',
#            'booth_list': ['60', '67'],
#            'booth_list_expanded': [60, 67],
#            'booth_count': 2,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 5,
#            's_no': 36,
#            'page_no_list': '80 - 81',
#            'ward_wise_booth_count': 9,
#            'lb_wise_booth_count': 19,
#            'trend_wise_booth_count': 4},
#           {'lb_name': 'ஆலங்குளம் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '0',
#            'ward_vp_type': 'ward',
#            'booth_list': ['68'],
#            'booth_list_expanded': [68],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'SF',
#            'page_no': 5,
#            's_no': 37,
#            'page_no_list': '82 - 83',
#            'ward_wise_booth_count': 9,
#            'lb_wise_booth_count': 19,
#            'trend_wise_booth_count': 4},
#           {'lb_name': 'ஆலங்குளம் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '0',
#            'ward_vp_type': 'ward',
#            'booth_list': ['69'],
#            'booth_list_expanded': [69],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'BS',
#            'page_no': 5,
#            's_no': 38,
#            'page_no_list': '84 - 85',
#            'ward_wise_booth_count': 9,
#            'lb_wise_booth_count': 19,
#            'trend_wise_booth_count': 4}]},
#         'WL': {'meta': {'total_booths': 4},
#          'data': [{'lb_name': 'ஆலங்குளம் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '0',
#            'ward_vp_type': 'ward',
#            'booth_list': ['53', '58,59', '64'],
#            'booth_list_expanded': [53, 58, 59, 64],
#            'booth_count': 4,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 5,
#            's_no': 39,
#            'page_no_list': '86 - 88',
#            'ward_wise_booth_count': 9,
#            'lb_wise_booth_count': 19,
#            'trend_wise_booth_count': 4}]},
#         'LL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '0',
#            'ward_vp_type': 'ward',
#            'booth_list': ['62'],
#            'booth_list_expanded': [62],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 5,
#            's_no': 40,
#            'page_no_list': '89 - 90',
#            'ward_wise_booth_count': 9,
#            'lb_wise_booth_count': 19,
#            'trend_wise_booth_count': 1}]}}},
#       '13': {'meta': {'total_booths': 1, 'ward_type': 'ward'},
#        'data': {'WW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '13',
#            'ward_vp_type': 'ward',
#            'booth_list': ['71'],
#            'booth_list_expanded': [71],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 6,
#            's_no': 41,
#            'page_no_list': '91 - 92',
#            'ward_wise_booth_count': 1,
#            'lb_wise_booth_count': 19,
#            'trend_wise_booth_count': 1}]}}},
#       '9': {'meta': {'total_booths': 2, 'ward_type': 'ward'},
#        'data': {'WW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '9',
#            'ward_vp_type': 'ward',
#            'booth_list': ['65'],
#            'booth_list_expanded': [65],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'SF',
#            'page_no': 6,
#            's_no': 42,
#            'page_no_list': '93 - 94',
#            'ward_wise_booth_count': 2,
#            'lb_wise_booth_count': 19,
#            'trend_wise_booth_count': 1}]},
#         'WL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '9',
#            'ward_vp_type': 'ward',
#            'booth_list': ['66'],
#            'booth_list_expanded': [66],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 6,
#            's_no': 43,
#            'page_no_list': '95 - 96',
#            'ward_wise_booth_count': 2,
#            'lb_wise_booth_count': 19,
#            'trend_wise_booth_count': 1}]}}},
#       '3': {'meta': {'total_booths': 1, 'ward_type': 'ward'},
#        'data': {'WL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '3',
#            'ward_vp_type': 'ward',
#            'booth_list': ['54'],
#            'booth_list_expanded': [54],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 6,
#            's_no': 44,
#            'page_no_list': '97 - 98',
#            'ward_wise_booth_count': 1,
#            'lb_wise_booth_count': 19,
#            'trend_wise_booth_count': 1}]}}},
#       '4': {'meta': {'total_booths': 1, 'ward_type': 'ward'},
#        'data': {'WL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'ஆலங்குளம் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '4',
#            'ward_vp_type': 'ward',
#            'booth_list': ['55'],
#            'booth_list_expanded': [55],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 6,
#            's_no': 45,
#            'page_no_list': '99 - 100',
#            'ward_wise_booth_count': 1,
#            'lb_wise_booth_count': 19,
#            'trend_wise_booth_count': 1}]}}}}}}}},
#  {'page_number': '',
#   'page_data': {'total_count_per_table': 21,
#    'page_data': [{'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '1',
#      'ward_vp_type': 'ward',
#      'booth_list': ['56'],
#      'booth_list_expanded': [56],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 6,
#      's_no': 46,
#      'page_no_list': '101 - 102',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '2',
#      'ward_vp_type': 'ward',
#      'booth_list': ['57'],
#      'booth_list_expanded': [57],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 6,
#      's_no': 47,
#      'page_no_list': '103 - 104',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '5',
#      'ward_vp_type': 'ward',
#      'booth_list': ['61'],
#      'booth_list_expanded': [61],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 6,
#      's_no': 48,
#      'page_no_list': '105 - 106',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '8',
#      'ward_vp_type': 'ward',
#      'booth_list': ['63'],
#      'booth_list_expanded': [63],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 6,
#      's_no': 49,
#      'page_no_list': '107 - 108',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 19,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'ஆலங்குளம் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
# ...
#            'ward_vp': 'இடைகால்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['274,275'],
#            'booth_list_expanded': [274, 275],
#            'booth_count': 2,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 17,
#            's_no': 158,
#            'page_no_list': '363 - 364',
#            'ward_wise_booth_count': 5,
#            'lb_wise_booth_count': 53,
#            'trend_wise_booth_count': 2}]},
#         'LW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'பாப்பாக்குடி',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'இடைகால்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['273'],
#            'booth_list_expanded': [273],
#            'booth_count': 1,
#            'trend': 'LW',
#            'sub_trend': 'DS',
#            'page_no': 17,
#            's_no': 159,
#            'page_no_list': '365 - 366',
#            'ward_wise_booth_count': 5,
#            'lb_wise_booth_count': 53,
#            'trend_wise_booth_count': 1}]},
#         'LL': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'பாப்பாக்குடி',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'இடைகால்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['276,277'],
#            'booth_list_expanded': [276, 277],
#            'booth_count': 2,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 17,
#            's_no': 160,
#            'page_no_list': '367 - 368',
#            'ward_wise_booth_count': 5,
#            'lb_wise_booth_count': 53,
#            'trend_wise_booth_count': 2}]}}},
#       'ரெங்கசமுத்திரம்': {'meta': {'total_booths': 3, 'ward_type': 'vp'},
#        'data': {'WL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'பாப்பாக்குடி',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'ரெங்கசமுத்திரம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['268'],
#            'booth_list_expanded': [268],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'SB',
#            'page_no': 18,
#            's_no': 161,
#            'page_no_list': '369 - 370',
#            'ward_wise_booth_count': 3,
#            'lb_wise_booth_count': 53,
#            'trend_wise_booth_count': 1}]},
#         'LL': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'பாப்பாக்குடி',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'ரெங்கசமுத்திரம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['269'],
#            'booth_list_expanded': [269],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'BD',
#            'page_no': 18,
#            's_no': 162,
#            'page_no_list': '371 - 372',
#            'ward_wise_booth_count': 3,
#            'lb_wise_booth_count': 53,
#            'trend_wise_booth_count': 2},
#           {'lb_name': 'பாப்பாக்குடி',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'ரெங்கசமுத்திரம்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['270'],
#            'booth_list_expanded': [270],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 18,
#            's_no': 163,
#            'page_no_list': '373 - 374',
#            'ward_wise_booth_count': 3,
#            'lb_wise_booth_count': 53,
#            'trend_wise_booth_count': 2}]}}},
#       'பள்ளக்கால்': {'meta': {'total_booths': 3, 'ward_type': 'vp'},
#        'data': {'LW': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'பாப்பாக்குடி',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'பள்ளக்கால்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['265,266'],
#            'booth_list_expanded': [265, 266],
#            'booth_count': 2,
#            'trend': 'LW',
#            'sub_trend': 'DS',
#            'page_no': 18,
#            's_no': 164,
#            'page_no_list': '375 - 376',
#            'ward_wise_booth_count': 3,
#            'lb_wise_booth_count': 53,
#            'trend_wise_booth_count': 2}]},
#         'LL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'பாப்பாக்குடி',
#            'lb_type': 'ஒன்றியம்',
#            'ward_vp': 'பள்ளக்கால்',
#            'ward_vp_type': 'vp',
#            'booth_list': ['267'],
#            'booth_list_expanded': [267],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 18,
#            's_no': 165,
#            'page_no_list': '377 - 378',
#            'ward_wise_booth_count': 3,
#            'lb_wise_booth_count': 53,
#            'trend_wise_booth_count': 1}]}}}}}}}},
#  {'page_number': '',
#   'page_data': {'total_count_per_table': 16,
#    'page_data': [{'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '0',
#      'ward_vp_type': 'ward',
#      'booth_list': ['294', '296'],
#      'booth_list_expanded': [294, 296],
#      'booth_count': 2,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 18,
#      's_no': 166,
#      'page_no_list': '379 - 380',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 2},
#     {'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '0',
#      'ward_vp_type': 'ward',
#      'booth_list': ['290', '292,293', '295'],
#      'booth_list_expanded': [290, 292, 293, 295],
#      'booth_count': 4,
#      'trend': 'WL',
#      'sub_trend': 'SD',
#      'page_no': 18,
#      's_no': 167,
#      'page_no_list': '381 - 383',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 5},
#     {'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '0',
#      'ward_vp_type': 'ward',
#      'booth_list': ['291'],
#      'booth_list_expanded': [291],
#      'booth_count': 1,
#      'trend': 'WL',
#      'sub_trend': 'SB',
#      'page_no': 18,
#      's_no': 168,
#      'page_no_list': '384 - 385',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 5},
#     {'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '0',
#      'ward_vp_type': 'ward',
#      'booth_list': ['297'],
#      'booth_list_expanded': [297],
#      'booth_count': 1,
#      'trend': 'LW',
#      'sub_trend': 'DS',
#      'page_no': 18,
#      's_no': 169,
#      'page_no_list': '386 - 387',
#      'ward_wise_booth_count': 8,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '1',
#      'ward_vp_type': 'ward',
#      'booth_list': ['298'],
#      'booth_list_expanded': [298],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 18,
#      's_no': 170,
#      'page_no_list': '388 - 389',
#      'ward_wise_booth_count': 3,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '1',
#      'ward_vp_type': 'ward',
#      'booth_list': ['299,300'],
#      'booth_list_expanded': [299, 300],
#      'booth_count': 2,
#      'trend': 'LW',
#      'sub_trend': 'DS',
#      'page_no': 19,
#      's_no': 171,
#      'page_no_list': '390 - 391',
#      'ward_wise_booth_count': 3,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 2},
#     {'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '5',
#      'ward_vp_type': 'ward',
#      'booth_list': ['298'],
#      'booth_list_expanded': [298],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'SS',
#      'page_no': 19,
#      's_no': 172,
#      'page_no_list': '392 - 393',
#      'ward_wise_booth_count': 2,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '5',
#      'ward_vp_type': 'ward',
#      'booth_list': ['302'],
#      'booth_list_expanded': [302],
#      'booth_count': 1,
#      'trend': 'LL',
#      'sub_trend': 'DD',
#      'page_no': 19,
#      's_no': 173,
#      'page_no_list': '394 - 395',
#      'ward_wise_booth_count': 2,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '3',
#      'ward_vp_type': 'ward',
#      'booth_list': ['301'],
#      'booth_list_expanded': [301],
#      'booth_count': 1,
#      'trend': 'WW',
#      'sub_trend': 'SB',
#      'page_no': 19,
#      's_no': 174,
#      'page_no_list': '396 - 397',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '2',
#      'ward_vp_type': 'ward',
#      'booth_list': ['300'],
#      'booth_list_expanded': [300],
#      'booth_count': 1,
#      'trend': 'LW',
#      'sub_trend': 'DS',
#      'page_no': 19,
#      's_no': 175,
#      'page_no_list': '398 - 399',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 1},
#     {'lb_name': 'முக்கூடல் பேரூர்',
#      'lb_type': 'பேரூராட்சி',
#      'ward_vp': '4',
#      'ward_vp_type': 'ward',
#      'booth_list': ['302'],
#      'booth_list_expanded': [302],
#      'booth_count': 1,
#      'trend': 'LL',
#      'sub_trend': 'DD',
#      'page_no': 19,
#      's_no': 176,
#      'page_no_list': '400 - 401',
#      'ward_wise_booth_count': 1,
#      'lb_wise_booth_count': 16,
#      'trend_wise_booth_count': 1}],
#    'grouped_page_data': {'முக்கூடல் பேரூர்': {'meta': {'lb_type': 'பேரூராட்சி',
#       'total_booths': 16},
#      'data': {'0': {'meta': {'total_booths': 8, 'ward_type': 'ward'},
#        'data': {'WW': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '0',
#            'ward_vp_type': 'ward',
#            'booth_list': ['294', '296'],
#            'booth_list_expanded': [294, 296],
#            'booth_count': 2,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 18,
#            's_no': 166,
#            'page_no_list': '379 - 380',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 2}]},
#         'WL': {'meta': {'total_booths': 5},
#          'data': [{'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '0',
#            'ward_vp_type': 'ward',
#            'booth_list': ['290', '292,293', '295'],
#            'booth_list_expanded': [290, 292, 293, 295],
#            'booth_count': 4,
#            'trend': 'WL',
#            'sub_trend': 'SD',
#            'page_no': 18,
#            's_no': 167,
#            'page_no_list': '381 - 383',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 5},
#           {'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '0',
#            'ward_vp_type': 'ward',
#            'booth_list': ['291'],
#            'booth_list_expanded': [291],
#            'booth_count': 1,
#            'trend': 'WL',
#            'sub_trend': 'SB',
#            'page_no': 18,
#            's_no': 168,
#            'page_no_list': '384 - 385',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 5}]},
#         'LW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '0',
#            'ward_vp_type': 'ward',
#            'booth_list': ['297'],
#            'booth_list_expanded': [297],
#            'booth_count': 1,
#            'trend': 'LW',
#            'sub_trend': 'DS',
#            'page_no': 18,
#            's_no': 169,
#            'page_no_list': '386 - 387',
#            'ward_wise_booth_count': 8,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 1}]}}},
#       '1': {'meta': {'total_booths': 3, 'ward_type': 'ward'},
#        'data': {'WW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '1',
#            'ward_vp_type': 'ward',
#            'booth_list': ['298'],
#            'booth_list_expanded': [298],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 18,
#            's_no': 170,
#            'page_no_list': '388 - 389',
#            'ward_wise_booth_count': 3,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 1}]},
#         'LW': {'meta': {'total_booths': 2},
#          'data': [{'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '1',
#            'ward_vp_type': 'ward',
#            'booth_list': ['299,300'],
#            'booth_list_expanded': [299, 300],
#            'booth_count': 2,
#            'trend': 'LW',
#            'sub_trend': 'DS',
#            'page_no': 19,
#            's_no': 171,
#            'page_no_list': '390 - 391',
#            'ward_wise_booth_count': 3,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 2}]}}},
#       '5': {'meta': {'total_booths': 2, 'ward_type': 'ward'},
#        'data': {'WW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '5',
#            'ward_vp_type': 'ward',
#            'booth_list': ['298'],
#            'booth_list_expanded': [298],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'SS',
#            'page_no': 19,
#            's_no': 172,
#            'page_no_list': '392 - 393',
#            'ward_wise_booth_count': 2,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 1}]},
#         'LL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '5',
#            'ward_vp_type': 'ward',
#            'booth_list': ['302'],
#            'booth_list_expanded': [302],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 19,
#            's_no': 173,
#            'page_no_list': '394 - 395',
#            'ward_wise_booth_count': 2,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 1}]}}},
#       '3': {'meta': {'total_booths': 1, 'ward_type': 'ward'},
#        'data': {'WW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '3',
#            'ward_vp_type': 'ward',
#            'booth_list': ['301'],
#            'booth_list_expanded': [301],
#            'booth_count': 1,
#            'trend': 'WW',
#            'sub_trend': 'SB',
#            'page_no': 19,
#            's_no': 174,
#            'page_no_list': '396 - 397',
#            'ward_wise_booth_count': 1,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 1}]}}},
#       '2': {'meta': {'total_booths': 1, 'ward_type': 'ward'},
#        'data': {'LW': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '2',
#            'ward_vp_type': 'ward',
#            'booth_list': ['300'],
#            'booth_list_expanded': [300],
#            'booth_count': 1,
#            'trend': 'LW',
#            'sub_trend': 'DS',
#            'page_no': 19,
#            's_no': 175,
#            'page_no_list': '398 - 399',
#            'ward_wise_booth_count': 1,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 1}]}}},
#       '4': {'meta': {'total_booths': 1, 'ward_type': 'ward'},
#        'data': {'LL': {'meta': {'total_booths': 1},
#          'data': [{'lb_name': 'முக்கூடல் பேரூர்',
#            'lb_type': 'பேரூராட்சி',
#            'ward_vp': '4',
#            'ward_vp_type': 'ward',
#            'booth_list': ['302'],
#            'booth_list_expanded': [302],
#            'booth_count': 1,
#            'trend': 'LL',
#            'sub_trend': 'DD',
#            'page_no': 19,
#            's_no': 176,
#            'page_no_list': '400 - 401',
#            'ward_wise_booth_count': 1,
#            'lb_wise_booth_count': 16,
#            'trend_wise_booth_count': 1}]}}}}}}}}]

# %%
with open("new2.json", "w", encoding="utf-8") as f:
    f.write(json.dumps(index_data_pages, ensure_ascii=False))

# %%
test_list = ["test1", "test2", "test3"]

test_dict = {test: idx+1 for idx, test in enumerate(test_list)}

type(test_dict["test1"])
# Out:
# int

# %%
x_axis = ["AIADMK", "DMK", "IND 3", "NTK", "Others", "CPI(M)"]
PARTY_WISE_COLORS = {
    "DMK": "#e82b1e",
    "VCK": "#0961b3",
    "BJP": "#e87007",
    "AIADMK": "#215e1b",
    "PMK": "#d9ce09",
    "NTK": "#141210",
    "Others": "#b3b4b5",
    "IND" : "#4c516d",
    "MDMK" :"#950606",
    "MNM" : "#d6204e",
    "IND" : "#4c516d",
    "PT"  :  "#66bd63",
    "CPI" : "#f04545",
    "CPIM" : "#ad4040",
    "INC" : "#5fb2d9",
    "IUML" : "#19d776",
    "DMDK":"#FDDA0D",
    "AMMK": "#234735"
}

dmk_red_color = "#f04545"

for item in x_axis:
    print(len(item.split(" ")))
# Out:
# 1
# 1
# 2
# 1
# 1
# 1

# %%
((308 - 308) != 0)
# Out:
# False

# %%
import json 
with open("ac_lb_mapping.json", "r", encoding="utf-8") as f:
    ac_lb_map = json.load(f)
